# %%
import requests
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin

# Get the cookbook overview page
base_url = "https://www.ddvculinary.com"
start_url = f"{base_url}/freecookbooks.php"
response = requests.get(start_url)
soup = BeautifulSoup(response.text, "html.parser")

# Create folder for saving PDFs
save_folder = "pdfs"
os.makedirs(save_folder, exist_ok=True)

# Find all green button links (cookbook pages)
cookbook_pages = []
for a in soup.find_all("a", href=True):
    href = a["href"]
    if href.endswith("-cb.php"):  # Matches cookbook detail pages
        full_url = urljoin(start_url, href)
        cookbook_pages.append(full_url)

print(f"Found {len(cookbook_pages)} cookbook detail pages.")

# Visit each cookbook page and find the PDF link
for page_url in cookbook_pages:
    try:
        page_response = requests.get(page_url)
        page_soup = BeautifulSoup(page_response.text, "html.parser")

        # Find the first link to a PDF file
        pdf_url = None
        for a in page_soup.find_all("a", href=True):
            if ".pdf" in a["href"].lower():
                pdf_url = urljoin(page_url, a["href"])
                break

        if pdf_url:
            filename = os.path.basename(pdf_url.split("?")[0])

            # Download and save PDF
            pdf_response = requests.get(pdf_url)
            save_path = os.path.join(save_folder, filename)
            with open(save_path, "wb") as f:
                f.write(pdf_response.content)
        else:
            print("No PDF found on this page.")

    except Exception as e:
        print(f"Error: {e}")
# Out:
# Found 217 cookbook detail pages.

# %%
# !pip uninstall -y PyPDF2
# !pip install pypdf

import os
from pypdf import PdfReader, PdfWriter

# Input and output folders
input_folder = "pdfs"
output_folder = "merged"
output_file = "All_Cookbooks_Merged.pdf"
os.makedirs(output_folder, exist_ok=True)

# Create a writer instance
writer = PdfWriter()

# Get all PDF files in the input folder
pdf_files = sorted([f for f in os.listdir(input_folder) if f.lower().endswith(".pdf")])

# Merge PDFs using PdfWriter
for pdf in pdf_files:
    pdf_path = os.path.join(input_folder, pdf)
    print(f"Adding: {pdf}")
    try:
        reader = PdfReader(pdf_path)
        for page in reader.pages:
            writer.add_page(page)
    except Exception as e:
        print(f"Skipping {pdf} due to error: {e}")

# Write the merged PDF
output_path = os.path.join(output_folder, output_file)
with open(output_path, "wb") as f_out:
    writer.write(f_out)
# Out:
# WARNING: Skipping PyPDF2 as it is not installed.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pypdf in c:\users\fie christina møller\appdata\roaming\python\python39\site-packages (5.4.0)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\fie christina møller\appdata\roaming\python\python39\site-packages (from pypdf) (4.12.2)
# Adding: 10-Creative-Quinoa-Recipes.pdf
# Adding: 101-Camping-And-Outdoor-Recipes.pdf
# Adding: 101-Pierogi-Filling-Ideas.pdf
# Adding: 101-Recipes-For-The-Deep-Fryer.pdf
# Adding: 101-Tips-And-Techniques-For-Cooking-Like-A-Chef.pdf
# Adding: 20-Easy-International-Recipes.pdf
# Adding: 200-Recipes-For-Italian-Dishes.pdf
# Adding: 300-Chicken-Recipes.pdf
# Adding: 300-Recipes-For-The-Grill.pdf
# Adding: 400-Refreshing-Punch-Recipes.pdf
# Adding: 5-Vietnamese-Recipes-To-Try-At-Home-From-Vietnam-Tourism-Board.pdf
# Adding: A-Dinner-Of-16th-Century-Spain.pdf
# Adding: A-Domestic-Cookbook-1866.pdf
# Adding: A-Flavour-Of-Scotland.pdf
# Adding: A-Little-Book-Of-Japanese-Recipes.pdf
# Adding: A-Taste-Of-Italy.pdf
# Adding: A-Taste-Of-Mexico.pdf
# Adding: A-Taste-Of-Thai-Chicken-Recipes.pdf
# Adding: A-Taste-Of-Thai-Coconut-Milk-Recipes.pdf
# Adding: A-Taste-Of-Thai-Favorite-Recipes.pdf
# Adding: A-Taste-Of-Thai-Rice-Noodle-Dishes.pdf
# Adding: A-Taste-Of-Thai-Vegetarian-Recipes.pdf
# Adding: A-Taste-Of-Troop-928.pdf
# Adding: Activity-Sheet-Popcorn-Recipes.pdf
# Adding: Africa-Recipes.pdf
# Adding: Amish-Recipes.pdf
# Adding: Australian-Recipes.pdf
# Adding: Authentic-Kentucky-Fried-Chicken-Recipes.pdf
# Adding: Barbecue-Recipes-2.pdf
# Adding: Barbeque-Recipes.pdf
# Adding: Basic-Kitchen-And-Food-Service-Management-2.pdf
# Adding: Basic-Kitchen-And-Food-Service-Management.pdf
# Adding: Beans-Cookbook.pdf
# Adding: Best-Bread-Production-Handbook.pdf
# Adding: Blue-Ribbon-Recipes.pdf
# Adding: Brazilian-Street-And-Party-Food-Favorites.pdf
# Adding: Bread-Baking-101.pdf
# Adding: Breads.pdf
# Adding: Breakfast-In-A-Flash.pdf
# Adding: Brew-Your-Own-Beer.pdf
# Adding: Cajun-Cooking.pdf
# Adding: Camp-Fire-Cooking.pdf
# Adding: Campbells-Cookbook.pdf
# Adding: Campfire-Cookbook.pdf
# Adding: Camping-Cooking-Recipes.pdf
# Adding: Canadian-Living-Cookbook.pdf
# Adding: Canola-Oil-Baking-Recipes.pdf
# Adding: Captain-Caribbean-Recipes.pdf
# Adding: Caribbean-Cookbook-2nd-Edition.pdf
# Adding: Caribbean-Cookbook.pdf
# Adding: Casserole-Recipes.pdf
# Adding: Celebrity-Pasta-Lovers-Cookbook.pdf
# Adding: Cheesecake-Recipes.pdf
# Adding: Chickpea-And-Lentil-Recipes.pdf
# Adding: Chili-Recipes.pdf
# Adding: Chinese-Japanese-Cook-Book-1914.pdf
# Adding: Chinese-Recipe-Sampler.pdf
# Adding: Clover-Leaf-Tuna-Recipes.pdf
# Adding: Coca-Cola-Recipes.pdf
# Adding: Coffee-Lovers.pdf
# Adding: Coleman-Family-Cookbook.pdf
# Adding: Cooking-Dried-Beans-Peas-And-Lentils.pdf
# Adding: Cooking-In-Old-Creole-Days-1904.pdf
# Adding: Cooking-Over-Campfire-Coals.pdf
# Adding: Cooking-With-Pulses-Beans-Peas-Lentils-And-Chickpeas.pdf
# Adding: Copycat-Insiders-Recipes.pdf
# Adding: Copycat-Recipe-Sampler.pdf
# Adding: Crockpot-Recipes-2.pdf
# Adding: Crockpot-Recipes.pdf
# Adding: Dales-Recipe-Book.pdf
# Adding: Danish-Recipes.pdf
# Adding: Delicious-Cajun-Recipes.pdf
# Adding: Delicious-Italian-Dishes.pdf
# Adding: Delicious-Puddings.pdf
# Adding: Delicious-Sandwich-Recipes.pdf
# Adding: Desserts-Of-Vitality.pdf
# Adding: Domestic-French-Cooking-1836.pdf
# Adding: Drying-Foods.pdf
# Adding: Dutch-Recipes.pdf
# Adding: Easy-Yeast-Breads-In-A-Bag.pdf
# Adding: EconoMeals.pdf
# Adding: Fifty-Choice-Recipes-Of-Mexican-And-Spanish-Dishes-1905.pdf
# Adding: Fine-Polish-Cuisine.pdf
# Adding: Finnish-Recipes.pdf
# Adding: Fish-And-Game-Recipe-Sampler.pdf
# Adding: Fish-Recipes-2.pdf
# Adding: Fish-Recipes.pdf
# Adding: Foil-Dinner-Recipes.pdf
# Adding: Food-Safety-Sanitation-And-Personal-Hygiene.pdf
# Adding: Full-O-Beans.pdf
# Adding: Generations-Of-Recipes.pdf
# Adding: Genuine-Puerto-Rican-Recipes.pdf
# Adding: German-Cookery-For-The-American-Home-1910.pdf
# Adding: Good-And-Cheap.pdf
# Adding: Good-RVfood-Cookbook.pdf
# Adding: Great-Recipes-From-The-South.pdf
# Adding: Great-Tastes.pdf
# Adding: Greek-Recipes.pdf
# Adding: Herbs-101.pdf
# Adding: Hog-Recipes.pdf
# Adding: How-To-Brew-Fruit-And-Kit-Wines.pdf
# Adding: How-To-Brew-Great-Beer-In-Under-Six-Hours.pdf
# Adding: How-To-Brew-Your-Own-Beer.pdf
# Adding: How-To-Easily-Homebrew-Your-Own-Delicious-Beers.pdf
# Adding: How-To-Make-Lefse-Instructions.pdf
# Adding: Ice-Cream-Recipes.pdf
# Adding: Indian-Recipes-II.pdf
# Adding: International-Cookbook-For-Quinoa.pdf
# Adding: International-Food-Recipes.pdf
# Adding: International-Recipes.pdf
# Adding: Irish-Angus-Beef-A-Recipe-Book.pdf
# Adding: Irish-Recipes-2.pdf
# Adding: Irish-Recipes-3.pdf
# Adding: Irish-Recipes.pdf
# Adding: Italian-Cooking-1900.pdf
# Adding: Italian-Recipe-Sampler.pdf
# Adding: Jamaican-Recipes.pdf
# Adding: Japanese-Recipes.pdf
# Adding: Jerky-Recipes.pdf
# Adding: Jewish-Recipes-Favorite-Recipes-Of-Ruth-Reingold.pdf
# Adding: Jewish-Recipes.pdf
# Adding: Joy-Of-Canning.pdf
# Adding: Know-Your-Spices.pdf
# Adding: Korean-Cooking.pdf
# Adding: Korean-Food-Recipes.pdf
# Adding: Latin-Grilling.pdf
# Adding: Lentils-Gems-In-The-Treasure-State.pdf
# Adding: Maine-Lobster-Recipes-For-The-Holidays.pdf
# Adding: Making-Bread-At-Home.pdf
# Adding: Malaysian-Recipes.pdf
# Adding: Malinis-Kitchen.pdf
# Adding: Metropolitan-Cookbook-1954.pdf
# Adding: Mexican-Recipe-Sampler.pdf
# Adding: Modern-Pastry-And-Plated-Dessert-Techniques.pdf
# Adding: Mouth-Watering-Fair-Recipes.pdf
# Adding: Native-American-Recipes.pdf
# Adding: Nelson-Family-Recipe-Book.pdf
# Adding: Norwegian-Recipes.pdf
# Adding: One-Hundred-And-One-Mexican-Dishes-1906.pdf
# Adding: Pacific-Cooks-Sweet-Treats-Edition-Baking-101.pdf
# Adding: Pacific-Islands-Cookbook.pdf
# Adding: Pie-Recipes.pdf
# Adding: Pierogi-Recipe-From-The-Polish-Countryside.pdf
# Adding: Pizza-Recipe-Sampler.pdf
# Adding: Pizza-Recipes.pdf
# Adding: Popcorn-Recipes-A-To-Z.pdf
# Adding: Popcorn-Recipes.pdf
# Adding: Portuguese-Recipes.pdf
# Adding: Potpourri-Recipes.pdf
# Adding: Practical-Italian-Recipes-For-American-Kitchens-1917.pdf
# Adding: Prize-Winning-Recipe-Sampler.pdf
# Adding: Puerto-Rican-Recipes.pdf
# Adding: Quick-And-Easy-Cooking.pdf
# Adding: Readers-Favorite-Recipes.pdf
# Adding: Real-Cajun.pdf
# Adding: Real-Restaurant-Recipes.pdf
# Adding: Recipe-Popcorn-On-Stove.pdf
# Adding: Recipes-From-Norway.pdf
# Adding: Russian-Recipes.pdf
# Adding: Salad-Recipe-Sampler.pdf
# Adding: Salad-Recipes-2.pdf
# Adding: Salad-Recipes.pdf
# Adding: Scottish-Cooking.pdf
# Adding: Simple-Italian-Cookery-1912.pdf
# Adding: Simple-Italian-Cookery.pdf
# Adding: Soup-Recipe-Sampler.pdf
# Adding: Soup-Recipes.pdf
# Adding: South-Of-The-Border-Freshness.pdf
# Adding: Spanish-Cuisine-Recipe-Book.pdf
# Adding: Spicy-Recipes.pdf
# Adding: Summer-Party-Cookbook.pdf
# Adding: Swedish-English-Cookbook-1897.pdf
# Adding: Swiss-Recipe-Collection.pdf
# Adding: Thai-Food-Good-Health.pdf
# Adding: Thanksgiving-Recipes.pdf
# Adding: The-Appetizer-Collection.pdf
# Adding: The-Art-And-Practice-Of-Sausage-Making.pdf
# Adding: The-Big-Book-Of-Cookies.pdf
# Adding: The-Blue-Grass-Cook-Book-1904.pdf
# Adding: The-Boston-Cooking-School-Cookbook-1896.pdf
# Adding: The-Brazilian-Table.pdf
# Adding: The-Bread-Baker-Bible.pdf
# Adding: The-British-Home-Cookery-Book-1915.pdf
# Adding: The-Chinese-Cook-Book-1917.pdf
# Adding: The-Chinese-Cookbook.pdf
# Adding: The-Christmas-Recipe-Cookbook.pdf
# Adding: The-Complete-Beef-Cookbook.pdf
# Adding: The-Creative-Homemaking-Guide-To-Casseroles.pdf
# Adding: The-Creative-Homemaking-Guide-To-Crock-Pot-Recipes.pdf
# Adding: The-Creative-Homemaking-Guide-To-Holiday-Recipes.pdf
# Adding: The-Creative-Homemaking-Guide-To-Salad-Dressings.pdf
# Adding: The-Creative-Homemaking-Guide-To-Soups-And-Chowders.pdf
# Adding: The-Creative-Homemaking-Guide-To-Zucchini-Recipes.pdf
# Adding: The-Cuban-Kitchen.pdf
# Adding: The-Essential-Kitchen.pdf
# Adding: The-Glasgow-Cookery-Book.pdf
# Adding: The-Good-Eats-Cookbook.pdf
# Adding: The-Graduate-Students-Guide-To-Indian-Recipes.pdf
# Adding: The-Great-British-Cookbook.pdf
# Adding: The-Home-Wine-Makers-Manual.pdf
# Adding: The-Home-Winemaking-Book.pdf
# Adding: The-International-Jewish-Cook-Book.pdf
# Adding: The-Oktoberfest-Cookbook.pdf
# Adding: The-Philippine-Cookbook.pdf
# Adding: The-Picayune-Creole-Cookbook.pdf
# Adding: The-Professional-Pizza-Guide.pdf
# Adding: The-Santesson-Recipe-Collection-Swedish-Cooking.pdf
# Adding: The-Seafood-Cookbook.pdf
# Ignoring wrong pointing object 4 0 (offset 0)
# Ignoring wrong pointing object 5 0 (offset 0)
# Adding: The-Ultimate-Chicken-Wing-Cookbook.pdf
# Adding: Tin-Foil-Cooking-Recipes.pdf
# Adding: Top-Secret-Recipes.pdf
# Adding: Traditional-Ukrainian-Dishes.pdf
# Adding: Traditional-Ukrainian-Recipes.pdf
# Adding: University-Of-California-Wine-Book.pdf
